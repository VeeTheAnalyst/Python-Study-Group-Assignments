# %% [markdown]
# # Task 1

# %%
Basic_Salary = 180000
Perf_Bonus = 45000
Total_Salary = (Basic_Salary + Perf_Bonus)

print(Total_Salary)

# if employee is eligible for premium benefits

print(Total_Salary >= 220000)
# Out:
# 225000
# True

# %% [markdown]
# # Task 2

# %%
Python = 72
SQL = 65
Excel = 80
Power_BI =75
Total_score = (Python + SQL + Excel + Power_BI)
Average_score = (Total_score / 4)

print(Total_score)
print(Average_score)

# to determine if a student passed
print(Average_score > 70)
# Out:
# 292
# 73.0
# True

# %% [markdown]
# # Task 3

# %%
Initial_stock = 250
Sold = 85
Remain = (Initial_stock - Sold)

print(Remain)

# to determine if the warehouse should reorder
print(Remain < 200)
# Out:
# 165
# True

# %% [markdown]
# # Task 4

# %%
Acc_bal = 520000
Withdraw = 150000
Rem_bal = (Acc_bal - Withdraw)

print(Rem_bal)

# to determine if the withdrawal will be approved
print(Acc_bal >= Withdraw)
# Out:
# 370000
# True

# %% [markdown]
# # BONUS

# %%
Laptop_Bag = 18500
Wireless_Mouse = 12000
Keyboard = 24500
USB_Drive = 5000
Total_Purchase = (Laptop_Bag + Wireless_Mouse + Keyboard + USB_Drive)

print(Total_Purchase)

# to determine if customer is qualified for discount
print(Total_Purchase >= 50000)

# to calculate the discount amount by 10%
Discount_amount = (10 / 100) * 60000

print(Discount_amount)

#to calculate the final amount to pay
Final_amount = (Total_Purchase - Discount_amount)

print(Final_amount)
# Out:
# 60000
# True
# 6000.0
# 54000.0
