# %% [markdown]
# # Task 1: Customer Registration System

# %%
Customer_name = "Glory Vivian"
Email_address = "gloryvivian@gmail.com"
Phone_number = "07038415153"
Country = "Nigeria"
Occupation = "Student"

print("Customer Registration")
print(" ")
print("Name:", Customer_name)
print("Email:", Email_address)
print("Phone:", Phone_number)
print("Country:", Country)
print("Occupation:", Occupation)
# Out:
# Customer Registration
#
# Name: Glory Vivian
# Email: gloryvivian@gmail.com
# Phone: 07038415153
# Country: Nigeria
# Occupation: Student

# %% [markdown]
# # Task 2: Hospital Patient Record

# %%
Patient_name = "Ayo"
Doctor = "George"
Diagnosis = "Malaria"
Blood_group = "O+"
Hospital = "General Hospital"

print("""
PATIENT RECORD

Patient:
Doctor: 
Diagnosis:
Blood Group:
Hospital:
""")
# Out:
# PATIENT RECORD
#
# Patient:
# Doctor:
# Diagnosis:
# Blood Group:
# Hospital:

# %% [markdown]
# # Task 3: AI Prompt Builder

# %%
Prompt = """
I am an AI Assistant.

Analyze customer feedbacks.

Identify common complaints.

Provide recommendations.

Generate a summary report.

Additional Instructions:
- Recommend realistic solutions.
- Use simple language that is easy to understand.
- Ensure the report is well organized.
"""
print(Prompt)
# Out:
# I am an AI Assistant.
#
# Analyze customer feedbacks.
#
# Identify common complaints.
#
# Provide recommendations.
#
# Generate a summary report.
#
# Additional Instructions:
# - Recommend realistic solutions.
# - Use simple language that is easy to understand.
# - Ensure the report is well organized.

# %% [markdown]
# # Task 4: Real-World Case Study Project

# %%
Customer_name = "Sarah Johnson"
Product_name = "Wireless Mouse"
Product_category = "Computer Accessories"
Customer_rating = "5 stars"
Customer_review = """

Customer Review
-------------------------
The product arrived on time, was easy to 
install,and exceeded my expectations.
I would definitely recommend it to others.

===================================
Thank you for your feedback!
===================================
"""
Report = '''
===================================
     CUSTOMER FEEDBACK REPORT
===================================
'''
print(Report)
print("Customer Name:", Customer_name)
print("Product:", Product_name)
print("Category:", Product_category)
print("Rating:", Customer_rating)
print(Customer_review)
# Out:
# ...
#      CUSTOMER FEEDBACK REPORT
# ...
#
# Customer Name: Sarah Johnson
# Product: Wireless Mouse
# Category: Computer Accessories
# Rating: 5 stars
#
#
# Customer Review
# -------------------------
# The product arrived on time, was easy to
# install,and exceeded my expectations.
# I would definitely recommend it to others.
#
# ...
# Thank you for your feedback!
# ...

# %% [markdown]
# # BONUS

# %%
Customer_name = "Sarah Johnson"
Product_name = "Wireless Mouse"
Product_category = "Computer Accessories"
Customer_rating = "5 stars"
Customer_review = """

Customer Review
-------------------------
The product arrived on time, was easy to 
install,and exceeded my expectations.
I would definitely recommend it to others.

===================================
Thank you for your feedback!

Company: Vee's Luxury Collections
Support Email: support@veesluxury.com
===================================
"""
Report = '''
===================================
     CUSTOMER FEEDBACK REPORT
===================================
'''
Welcome_message = '''
Welcome to Vee's Luxury Collections
Customer Feedback Management System
'''
Quote = "The customer said, \"This is the best wireless mouse I have ever used!\""

print(Welcome_message)
print(Report)
print("Customer Name:", Customer_name)
print("Product:", Product_name)
print("Category:", Product_category)
print("Rating:", Customer_rating)
print(Customer_review)
print()
print(Quote)
# Out:
# Welcome to Vee's Luxury Collections
# Customer Feedback Management System
#
#
# ...
#      CUSTOMER FEEDBACK REPORT
# ...
#
# Customer Name: Sarah Johnson
# Product: Wireless Mouse
# Category: Computer Accessories
# Rating: 5 stars
#
#
# Customer Review
# -------------------------
# The product arrived on time, was easy to
# install,and exceeded my expectations.
# I would definitely recommend it to others.
#
# ...
# Thank you for your feedback!
#
# Company: Vee's Luxury Collections
# Support Email: support@veesluxury.com
# ...
#
#
# The customer said, "This is the best wireless mouse I have ever used!"
