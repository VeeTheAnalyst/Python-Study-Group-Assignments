# %% [markdown]
# # Exercise 1: Printing Text(Beginner)

# %%
print("Hello, World!")
print("My name is Vivian")
print("I am learning Python.")
print("Programming is exciting!")
# Out:
# Hello, World!
# My name is Vivian
# I am learning Python.
# Programming is exciting!

# %% [markdown]
# # Exercise 2: Multiple Print Statements

# %%
print("My favorite food is Yam and Egg sauce.")
print("My favorite movie is City Hunter.")
print("My favourite sport is Swimming.")
print ("My favorite color is Violet.")
# Out:
# My favorite food is Yam and Egg sauce.
# My favorite movie is City Hunter.
# My favourite sport is Swimming.
# My favorite color is Violet.

# %% [markdown]
# #Exercise 3:

# %%
print(15 + 5)
print(30 - 12)
print(9 * 8)
print(72/2)
print(18 % 5)
print(10 // 3)
print(5**2)
# Out:
# 20
# 18
# 72
# 36.0
# 3
# 3
# 25

# %% [markdown]
# #Exercise 4:

# %%
# Display programming language
print("Python")

# To display the subject
print("Programming")

# To display the lesson number
print("Lesson One")
# Out:
# Python
# Programming
# Lesson One

# %% [markdown]
# #Exercise 5:

# %%
print("Vivian is an English name")
print("I look forward to being a professional Data Analyst")
print("I hope for a better Nigeria")
print(25 + 75)
print(40 // 6)
print(8 ** 2)
print("It is well")
# Out:
# Vivian is an English name
# I look forward to being a professional Data Analyst
# I hope for a better Nigeria
# 100
# 6
# 64
# It is well
