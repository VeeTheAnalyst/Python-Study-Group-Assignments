# %% [markdown]
# # Task 1: Student Score Tracker

# %%
score = 60   #initial value
score += 15
score -= 5
score *= 2
print("Final score =", score)
# Out:
# Final score = 140

# %% [markdown]
# # Task 2: Digital Wallet Simulator

# %%
Balance = 25000
Balance += 8500   #Deposit
Balance -= 4200   #Withdraw
Balance /= 3      #divided amongst 3 savings account
print("Final Balance :", Balance)
print(type(Balance))
# Out:
# Final Balance : 9766.666666666666
# <class 'float'>

# %%
# allowing the user to enter withdrawal and deposit
Withdrawal = input("Enter withdrawal amount :")
Deposit = input("Enter deposit amount :")
# Out:
# Enter withdrawal amount : #4,200
# Enter deposit amount : #8,500

# %% [markdown]
# # Task 3: Inventory Management System

# %%
Stock = 150
Stock -= 28
Stock += 75
Stock //= 12
print(Stock, "full cartons")
# Out:
# 16 full cartons

# %% [markdown]
# # Bonus Challenge

# %%
#allowin user to answer questions
input("Number of initial stock :")
input("Number of sold items :")
input("How many items arrived :")
input("How many items fit into one carton :")
input("Remaining stock after sales :")
input("Updated stock after restocking :")
input("Number of full cartons :")
# Out:
# Number of initial stock : 150
# Number of sold items : 28
# How many items arrived : 75
# How many items fit into one carton : 12
# Remaining stock after sales : 122
# Updated stock after restocking : 197
# Number of full cartons : 16
# '16'

# %%
#checking the remaing items
Stock = 150
Stock -= 28
Stock += 75
Stock //= 12
Stock %= 12
print(Stock)
input("Remaining loose items :")
# Out:
# 4
# Remaining loose items : 4
# '4'
