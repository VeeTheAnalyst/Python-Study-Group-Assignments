# %% [markdown]
# # Exercise 1

# %%
Name = "Vivian"
Age = 20
Country = "Nigeria"

print(Name)
print(Age)
print(Country)
# Out:
# Vivian
# 20
# Nigeria

# %% [markdown]
# # Exercise 2

# %%
Basic_Salary = 180000
Bonus = 35000
Total_Salary = Basic_Salary + Bonus

print(Total_Salary)
# Out:
# 215000

# %% [markdown]
# # Exercise 3

# %%
name = input("Enter your name:")
print(name)
